# %%
import newspaper
newspaper.languages()
# Out:
# Your available languages are:
#
# input code		full name
#   ar			  Arabic
#   zh			  Chinese
#   ko			  Korean
#   sv			  Swedish
#   no			  Norwegian
#   nl			  Dutch
#   mk			  Macedonian
#   it			  Italian
#   id			  Indonesian
#   de			  German
#   hu			  Hungarian
#   en			  English
#   da			  Danish
#   tr			  Turkish
#   he			  Hebrew
#   fr			  French
#   pt			  Portuguese
#   ru			  Russian
#   vi			  Vietnamese
#   nb			  Norwegian (Bokmål)
#   es			  Spanish
#   fi			  Finnish

# %%
cbs_paper = newspaper.build('http://cbs.com', memoize_articles=False)
print (cbs_paper.size())
# Out:
# 236

# %%
# getting all categories 
cbs_paper.category_urls()
# Out:
# ['http://cbs.com/the-millers',
#  'http://cbs.com',
#  'http://cbs.seenon.com',
#  'http://cbs.com/schedule',
#  'http://cbs.com/live-tv',
#  'http://cbs.com/all-access',
#  'http://cbs.com/watch',
#  'http://cbs.com/superbowl',
#  'http://cbs.com/cbs_cares',
#  'http://cbs.com/shows',
#  'http://www.cbs.com']

# %%
#Extracting Source brand & description
print(cbs_paper.brand)
print(cbs_paper.description)
# Out:
# cbs
# television, TV, video, CBS TV, Columbia Broadcast System, watch online video, watch tv, soap opera video, David Letterman, CSI, Big Brother, NCIS, The Price is Right, the Young and the Restless, Guiding Light, As the World Turns, Survivor, Two and a Half Men, The Amazing Race, Star Trek, Jericho.

# %%
# print all articles 
print(cbs_paper.articles)
print (len(cbs_paper.articles))
# Out:
# [<newspaper.article.Article object at 0x7fe724548f98>, <newspaper.article.Article object at 0x7fe7244fc978>, <newspaper.article.Article object at 0x7fe7244d6b70>, <newspaper.article.Article object at 0x7fe728598d68>, <newspaper.article.Article object at 0x7fe7244a7b70>, <newspaper.article.Article object at 0x7fe724525cc0>, <newspaper.article.Article object at 0x7fe72858ca58>, <newspaper.article.Article object at 0x7fe724552be0>, <newspaper.article.Article object at 0x7fe7244daac8>, <newspaper.article.Article object at 0x7fe72454d668>, <newspaper.article.Article object at 0x7fe7244ef390>, <newspaper.article.Article object at 0x7fe724548160>, <newspaper.article.Article object at 0x7fe72453a6a0>, <newspaper.article.Article object at 0x7fe724552f98>, <newspaper.article.Article object at 0x7fe7244da6a0>, <newspaper.article.Article object at 0x7fe7285c2fd0>, <newspaper.article.Article object at 0x7fe724513828>, <newspaper.article.Article object at 0x7fe7244ef6a0>, <newspaper.article.Article object at 0x7fe728598320>, <newspaper.article.Article object at 0x7fe7244a7400>, <newspaper.article.Article object at 0x7fe728584b00>, <newspaper.article.Article object at 0x7fe7244fc320>, <newspaper.article.Article object at 0x7fe7244fd358>, <newspaper.article.Article object at 0x7fe7244b44a8>, <newspaper.article.Article object at 0x7fe72453d5f8>, <newspaper.article.Article object at 0x7fe7244b48d0>, <newspaper.article.Article object at 0x7fe724431128>, <newspaper.article.Article object at 0x7fe724552358>, <newspaper.article.Article object at 0x7fe724513908>, <newspaper.article.Article object at 0x7fe724543160>, <newspaper.article.Article object at 0x7fe724543e80>, <newspaper.article.Article object at 0x7fe7244daef0>, <newspaper.article.Article object at 0x7fe724513320>, <newspaper.article.Article object at 0x7fe72454dac8>, <newspaper.article.Article object at 0x7fe724513b38>, <newspaper.article.Article object at 0x7fe7244fcb70>, <newspaper.article.Article object at 0x7fe72454ddd8>, <newspaper.article.Article object at 0x7fe7244e73c8>, <newspaper.article.Article object at 0x7fe7245484a8>, <newspaper.article.Article object at 0x7fe7285981d0>, <newspaper.article.Article object at 0x7fe724552b38>, <newspaper.article.Article object at 0x7fe724548278>, <newspaper.article.Article object at 0x7fe7244e30f0>, <newspaper.article.Article object at 0x7fe7245487b8>, <newspaper.article.Article object at 0x7fe7244fc7b8>, <newspaper.article.Article object at 0x7fe72858cf98>, <newspaper.article.Article object at 0x7fe728570630>, <newspaper.article.Article object at 0x7fe7244b40f0>, <newspaper.article.Article object at 0x7fe724513a58>, <newspaper.article.Article object at 0x7fe7244b42e8>, <newspaper.article.Article object at 0x7fe724552c88>, <newspaper.article.Article object at 0x7fe72453d588>, <newspaper.article.Article object at 0x7fe724548d68>, <newspaper.article.Article object at 0x7fe7245257b8>, <newspaper.article.Article object at 0x7fe724513518>, <newspaper.article.Article object at 0x7fe724548e48>, <newspaper.article.Article object at 0x7fe728598f60>, <newspaper.article.Article object at 0x7fe72858fc88>, <newspaper.article.Article object at 0x7fe7244dae10>, <newspaper.article.Article object at 0x7fe7244ef278>, <newspaper.article.Article object at 0x7fe72858c978>, <newspaper.article.Article object at 0x7fe724513b00>, <newspaper.article.Article object at 0x7fe724513978>, <newspaper.article.Article object at 0x7fe728598390>, <newspaper.article.Article object at 0x7fe724513e48>, <newspaper.article.Article object at 0x7fe7244b7438>, <newspaper.article.Article object at 0x7fe7245132e8>, <newspaper.article.Article object at 0x7fe724513c18>, <newspaper.article.Article object at 0x7fe72454d5c0>, <newspaper.article.Article object at 0x7fe7244e3128>, <newspaper.article.Article object at 0x7fe7244fd1d0>, <newspaper.article.Article object at 0x7fe724431c18>, <newspaper.article.Article object at 0x7fe7285849b0>, <newspaper.article.Article object at 0x7fe7244fcdd8>, <ne ...
# 236

# %%
#Downloading an Article
first_article = cbs_paper.articles[0]
first_article.download()
print(first_article.html)
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" class="">
# <head>
#         <script type="text/javascript" src="//js-sec.indexww.com/ht/ls-cbs.js" async></script>
#         <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
#     <meta http-equiv="Content-Type" content="text/html;charset=utf-8"/>
#     <meta content="app-id=530168168" name="apple-itunes-app">
#     <meta property="og:site_name" content="CBS"/>
# <meta name="viewport" content="width=device-width, initial-scale=0.5, maximum-scale=1.0, user-scalable=no" />
#
#     <link rel="alternate" href="android-app://com.cbs.app/cbs/http://www.cbs.com/shows/amazing_race/video/?campaign=ftag:ADLbe6cacd&fg=1" />
#
#             <meta property="og:title" content="The Amazing Race Video - The Race Begins - CBS.com"/>
#
#             <meta property="og:description" content=""/>
#
#             <meta property="og:type" content="article"/>
#
#     <meta property="og:image" content=""/>
#
#
#
#
#
#
#
#
#
#             <meta name="application-name" content=""/>            <meta name="msapplication-TileImage" content="/assets/images/site/cbs_pin.png"/>            <meta name="msapplication-TileColor" content="#3070b1"/>            <meta name="msApplication-ID" content="App"/>            <meta name="CBS.Win8_dx3spxfjvhtp4" content="App"/>
#
#
#     <meta property="fb:app_id" content="30708972585"/>
#     <meta property="fb:pages" content="47360808996"/>
#     <meta name="keywords" content=""/>
#     <meta name="description" content=""/>
#
#     <meta name="twitter:widgets:csp" content="on">
#
#     <title>The Amazing Race Video - The Race Begins - CBS.com</title>
#     <link rel="shortcut icon" href="http://www.cbsstatic.com/sitecommon/images/favicon.ico"/>
#             <link rel="canonical" href="http://www.cbs.com/shows/amazing_race/video/"/>
#                 <link rel="stylesheet" type="text/css" href="http://wwwimage.cbsstatic.com/assets/min/css/2013/v2.video.min.css?20161028-233225" />
# <link rel="stylesheet" type="text/css" href="http://wwwimage.cbsstatic.com/assets/min/css/min/com.cbs.min.css?20161028-233225" />
# <link rel="stylesheet" type="text/css" href="http://wwwimage.cbsstatic.com/assets/min/css/2015/r1/cbs.q2.min.css?20161028-233225" />
# <link rel="stylesheet" type="text/css" href="http://wwwimage.cbsstatic.com/assets/min/css/2012/r1/amazing_race.min.css?20161028-233225" />
# <link rel="stylesheet" type="text/css" href="http://wwwimage.cbsstatic.com/assets/min/css/2015/r1/cbs.show.video.q2.min.css?20161028-233225" />
# <link rel="stylesheet" type="text/css" href="http://wwwimage.cbsstatic.com/assets/min/css/2012/r1/video_carousel.min.css?20161028-233225" />
# <link rel="stylesheet" type="text/css" href="http://wwwimage.cbsstatic.com/assets/min/css/2015/r1/video_carousel.min.css?20161028-233225" />
#
#         <!--[if IE]>
#     <link rel="stylesheet" type="text/css" href="/assets/css/2012/r1/ie.css"/>
#     <![endif]-->
#
#     <!--[if lt IE 9]>
#     <link rel="stylesheet" type="text/css" href="/assets/css/2012/r1/ie78.css"/>
#     <![endif]-->
#
#     <script type="text/javascript" src="/assets/js/require.js"></script>
# <script type="text/javascript">
#     require.config({baseUrl: '/assets/js/cbs/'});
# </script>
#     <script type="text/javascript" src="/assets/min/js/min/com.cbs.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/jquery.adMarquee.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/swfobject_2.2.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/cbs/v2/video/cbsplayer.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/cbs/v2/video/cbscastplayer.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/videoPlayerFunctions.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/expose.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/jquery.cookie.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/jquery.protify-0.3.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/appendSC.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/deleteAdvCookie.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/setAdvCookie.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/cbs/module/video/cbs.module.video.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/cbs/v2/carousel/cbs.v2.carousel.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/cbs/v3/tealium/cbs.v3.customVideoTealium.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/templates/cbssync.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/jCarousel/jquery.jcarousel.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/templates/carousels/videoAdaptive.min.js?20161028-233225"></script>
# <script type="text/javascript" src="/assets/min/js/underscore.min.js?20161028-233225"></script>
#
#     <script language="JavaScript">var DW_page_type = "VIDEO";</script>
#             <script language="JavaScript" type="text/javascript" src="/assets/js/dw_site/amazing_race.js?20161028-233225"></script>
#                 <script language="JavaScript" type="text/javascript" src="/assets/js/dw_site/v1_5/amazing_race.js?20161028-233225"></script>
#                 <script language="JavaScript" type="text/javascript" src="/assets/min/js/dw_global_mr45.min.js"></script>
#     <script type="text/javascript" src="//dw.cbsi.com/js/dw.js"></script>
#
# <script type="text/javascript">
#     var DW_referer = "";
#     var DW_srcURL = "http%3A%2F%2Fwww.cbs.com%2Fshows%2Famazing_race%2Fvideo%2F";
#     var DW_ctype = "";
#     var DW_cval = "";
#
#         DW_ursuid = "";
#
#     var __page_uuid = '';
#     try {
#         __page_uuid = uuid.v4();
#     } catch (e){
#         __page_uuid = "3258aa81-ede0-4d68-8786-3d0ecffd1d5c";
#     }
#
#     $.cookie('__page_uuid', __page_uuid, {path: '/'});
#
#     DW.pageParams = { UID: CBS.getUID(), siteid: DW_siteid, onid: onidFinal, pguid: __page_uuid, viewguid: __page_uuid, v16: __page_uuid, ptid: DW_ptid, ctype: DW_ctype, cval: DW_cval, ursuid: DW_ursuid };
#
# </script>
#     <script type="text/javascript">
#         window.fbAsyncInit = function() {
#             FB.init({appId: '30708972585', status: true, cookie: true, xfbml: true, version: 'v2.5'});
#         };
#
#         (function() {
#             var fb = document.createElement('script');
#             fb.type = 'text/javascript';
#             fb.async = true;
#             fb.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'connect.facebook.net/en_US/sdk.js';
#             var s = document.getElementsByTagName('script')[0];
#             s.parentNode.insertBefore(fb, s);
#         })();
#
#         (function() {
#             var po = document.createElement('script');
#             po.type = 'text/javascript';
#             po.async = true;
#             po.src = 'https://apis.google.com/js/plusone.js';
#             var s = document.getElementsByTagName('script')[0];
#             s.parentNode.insertBefore(po, s);
#         })();
#
#         var show = new CBS.Show({id:21028});
#
#     </script>
#
#             <script type="text/javascript">window._taboola = window._taboola || [];
#                 _taboola.push({video:"auto"});
#                 !function (e, f, u) {
#                 e.async = 1;
#                 e.src = u;
#                 f.parentNode.insertBefore(e, f);
#                 }(document.createElement("script"),
#                 document.getElementsByTagName("script")[0],
#                 "//cdn.taboola.com/libtrc/cbsinteractive-cbscom/loader.js");
#                 CBS.Registry.context_override.contentWidget = "Below Content Thumbnails";
#                 $( document ).ready(function() { CBS.Tracking.clickTrackTaboola("Below Content Thumbnails"); });</script>
#     <script src="//tags.tiqcdn.com/utag/cbsi/main/prod/utag.sync.js"></script>
#
#     <script type="text/javascript" src="//native.sharethrough.com/assets/sfp.js" async></script>
#
# </head>
#
# <body id="showBody"
#       class="all-access_ cbs-show-landing page_type_HOME PRIMETIME_REALITY ">
#     <!--[if IE]>
#     <div id="IEroot">
#     <![endif]-->
#
#         <div id="cbs-ad-skin"></div>
#
#         <div id="cbs-page"  >
#             <style>
#     /* Lato must be loaded before the browser renders any view. */
#
#     @font-face {
#         font-family: LatoRegular;
#         src: url('/assets/fonts/Lato/Lato-Regular.ttf');
#     }
#
#     @font-face {
#         font-family: OswaldRegular;
#         src: url('/assets/fonts/Oswald/Oswald-Regular.ttf');
#     }
# </style>
#
#     <script src="/assets/min/js/global_header.min.js?20161028-233225"></script>
#     <script src="/assets/min/js/global_login.min.js?20161028-233225"></script>
#     <script src="/assets/min/js/templates/search.min.js?20161028-233225"></script>
#
#     <link rel="stylesheet" href="http://wwwimage.cbsstatic.com/assets/min/css/2015/r1/video_carousel_header.min.css?20161028-233225">
#     <link rel="stylesheet" href="http://wwwimage.cbsstatic.com/assets/min/css/2016/r1/header.min.css?20161028-233225" charset="utf-8">
#     <link rel="stylesheet" href="http://wwwimage.cbsstatic.com/assets/min/css/login.min.css?20161028-233225">
#             <link rel="stylesheet" href="http://wwwimage.cbsstatic.com/assets/min/css/shows/headerOffset.min.css?20161028-233225">
#
# <script type="text/javascript">
#     CBS.Host = 'http://www.cbs.com';
#     CBS.Registry.facebook_app_id = "30708972585";
#     CBS.Registry.google_client_id = "622419776613.apps.googleusercontent.com";
#     CBS.Registry.user_auth = false;
#     CBS.Registry.ssl = true;
#     CBS.Registry.host = "www.cbs.com";
#     CBS.Registry.platform = {"isMobile":false,"isWebView":false,"current":"DESKTOP","isHandheld":false};
#     CBS.Registry.chromecast.receiver_id = "0BBDC217";
#     CBS.Registry.recurly_public_key = "ewr1-Tos8OMtfKABulJFWhaRxsX";
#
#         CBS.Registry.login.authToken = 'Kh5jeItMVN0DQq/C0v3GICz5HIX2dbhczxMb6GA8Aqg=';
#
#
#
#
#     $(function () {
#         $('#shows-link').focus(function () {
#             $('#shows-link').trigger('mouseover');
#
#
#         });
#         $('#shows-link').focusout(function () {
#             $('#shows-link').trigger('mouseout');
#         });
#     });
#     try {
#         CBS.UserAuthStatus = false;
#     } catch (e) {
#     }
#
# </script>
#
# <div id="loginModal" class="isHidden">
#
#     <iframe name="cbsLoginIframe" id="cbsLoginIframe" style="display:none;"></iframe>
#
#     <div class="titleContainer">
#         <div id="titleText"> Sign In to CBS</div>
#         <img id='closeButton' onclick="GlobalLogin.closeModal()" alt="Close" src="/assets/images/headers/close.png">
#     </div>
#     <div class="copyContainer"></div>
#     <!-- THis is the Sign Up / Login view -->
#     <div id='signInSignUpView'>
#         <div id="socialAccountSignIn">
#             <div> With Social Account</div>
#             <a onclick='CBSAccount.session.facebook()'></a> <a onclick='CBSAccount.session.twitter(true)'></a> <a
#                 onclick='CBSAccount.session.gplus.manualAuth()'></a>
#         </div>
#         <div id="errorMessage"></div>
#         <div id="emailSignIn"> With Email</div>
#
#
#         <form target="cbsLoginIframe" action='//www.cbs.com/account/login' method="POST"
#               onsubmit="return GlobalLogin.submitLogin(this);">
#             <input name='j_username' type="text" placeholder="Email">
#             <input name='j_password' type="password" placeholder="Password">
#             <input name="_remember_me" type="hidden" value="1">
#             <input type="hidden" name="tk_trp" value="Kh5jeItMVN0DQq/C0v3GICz5HIX2dbhczxMb6GA8Aqg="/>
#             <div id="forgotPasswordSignInContainer">
#                 <div id="forgotPasswordLink" onclick="GlobalLogin.displayForgotPasswordView()"> Forgot Password</div>
#                 <input type="submit" value="Sign In">
#             </div>
#         </form>
#
#         <div id='dividerContainer'>
#             <div class="divider"></div>
#             <div>Or</div>
#             <div class="divider"></div>
#         </div>
#         <div id="signUpContainer">
#             <div> Don't have an account? Create one for FREE!</div>
#             <a class="buttonLink" href='/user/signup/'>
#                 <div>Sign Up</div>
#             </a>
#         </div>
#     </div>
#     <!-- End of signInSignUpView -->
#
#     <!-- This is the Forgot Password view -->
#
#     <div id='forgotPasswordView' style='display: none;'> <!-- This is initially hidden -->
#         <div class="messageContainer">
#             <div> Forgot your password?</div>
#             <div id='forgotPasswordHeader'> Enter your email address below and we'll send you an email with instructions
#                 to create a new password.
#             </div>
#         </div>
#         <form target='cbsLoginIframe' action='//www.cbs.com/account/forgot_password'
#               onsubmit="return GlobalLogin.submitForgotPassword(this)" method='POST'>
#             <input name='email' type="text" placeholder="Email">
#             <div id='cancelSendContainer'>
#                 <div onclick="GlobalLogin.cancelForgotPassword()"> Cancel</div>
#                 <input type='submit' value='Send Password'>
#             </div>
#         </form>
#     </div>
#
#
#     <!-- End of forgotPasswordView -->
#
#     <!-- This is the Forgot Password Confirmation View -->
#
#     <div id='forgotPasswordConfirmationView' style='display:none;'>
#
#         <div class="messageContainer">
#             <div> Email Sent</div>
#             <div> Instructions to change your password should arrive in your inbox in a few moments.</div>
#         </div>
#
#         <div onclick="GlobalLogin.showSignIn()"> Back to Sign In</div>
#
#     </div>
#
#     <!-- End of Forgot Password Confirmation View -->
#
#     <!-- This is the Logged In View -->
#     <div id="profileView" style='display: none;'> <!-- Should be hidden initially -->
#         <a href="/user/settings">Profile</a>
#         <a href="/all-access/account/">CBS All Access Account </a>
#         <a href="javascript:CBSAccount.session.logout()">Logout</a>
#         <a href="https://cbsi.secure.force.com/CBSi/knowledgehome?referer=cbs.com">Help </a>
#     </div>
#     <!-- End of Logged In view -->
#
# </div>
# <!-- Begin of new header -->
# <header id="globalHeaderContainer" class="happyBlue">
#     <section class="widthWrapper">
#         <div id="globalNav">
#             <div class="lrGutter">
#                 <a href="/" id="cbsLogo" class="left "></a>
#
#                 <nav id="globalNavItems" class="left">
#                     <div class="globalShowsDropDownWrapper">
#                         <a href="/shows/" id="initGlobalShowsDropDown" data-role="main-nav-item"
#                            class="">SHOWS</a>
#                         <div id="globalShowsDropDown" class="expanded">
#                             <div class="spacer"></div>
#                             <div class="showList">
#
#                                 <section class="widthWrapper">
#                                     <div class="lrGutter">
#                                         <a href="javascript:void(0);" class="close"></a>
#                                         <div class="section">
#     <h4>Drama</h4>
#     <ul class="menu-section-items drama">
#         <li class="show-list-item"><a href="/shows/american-gothic/" target="_parent" class="show-nav-link">American Gothic</a></li><li class="show-list-item"><a href="/shows/beauty-and-the-beast/" target="_parent" class="show-nav-link">Beauty and the Beast</a></li><li class="show-list-item"><a href="/shows/beverly-hills-90210/" target="_parent" class="show-nav-link">Beverly Hills 90210</a></li><li class="show-list-item"><a href="/shows/blue_bloods/" target="_parent" class="show-nav-link">Blue Bloods</a></li><li class="show-list-item"><a href="/shows/braindead/" target="_parent" class="show-nav-link">BrainDead</a></li><li class="show-list-item"><a href="/shows/bull/" target="_parent" class="show-nav-link">Bull</a></li><li class="show-list-item"><a href="/shows/code-black/" target="_parent" class="show-nav-link">Code Black</a></li><li class="show-list-item"><a href="/shows/criminal_minds/" target="_parent" class="show-nav-link">Criminal Minds</a></li><li class="show-list-item"><a href="/shows/criminal-minds-beyond-borders/" target="_parent" class="show-nav-link">Criminal Minds: Beyond Borders</a></li><li class="show-list-item"><a href="/shows/csi/" target="_parent" class="show-nav-link">CSI: Crime Scene Investigation</a></li><li class="show-list-item"><a href="/shows/csi-miami/" target="_parent" class="show-nav-link">CSI: Miami</a></li><li class="show-list-item"><a href="/shows/doubt/" target="_parent" class="show-nav-link">Doubt</a></li><li class="show-list-item"><a href="/shows/elementary/" target="_parent" class="show-nav-link">Elementary</a></li><li class="show-list-item"><a href="/shows/extant/" target="_parent" class="show-nav-link">Extant</a></li><li class="show-list-item"><a href="/shows/flashpoint/" target="_parent" class="show-nav-link">Flashpoint</a></li><li class="show-list-item"><a href="/shows/the-game/" target="_parent" class="show-nav-link">The Game</a></li><li class="show-list-item"><a href="/shows/ghost-whisperer/" target="_parent" class="show-nav-link">Ghost Whisperer</a></li><li class="show-list-item"><a href="/shows/the_good_wife/" target="_parent" class="show-nav-link">The Good Wife</a></li><li class="show-list-item"><a href="/shows/the-guardian/" target="_parent" class="show-nav-link">The Guardian</a></li><li class="show-list-item"><a href="/shows/hawaii_five_0/" target="_parent" class="show-nav-link">Hawaii Five-0</a></li><li class="show-list-item"><a href="/shows/hawaii-five-O-classic/" target="_parent" class="show-nav-link">Hawaii Five-0 Classic</a></li><li class="show-list-item"><a href="/shows/jag/" target="_parent" class="show-nav-link">JAG</a></li><li class="show-list-item"><a href="/shows/jericho/" target="_parent" class="show-nav-link">Jericho</a></li><li class="show-list-item"><a href="/shows/life-unexpected/" target="_parent" class="show-nav-link">Life Unexpected</a></li><li class="show-list-item"><a href="/shows/limitless/" target="_parent" class="show-nav-link">Limitless</a></li><li class="show-list-item"><a href="/shows/macgyver/" target="_parent" class="show-nav-link">MacGyver</a></li><li class="show-list-item"><a href="/shows/macgyver-classic/" target="_parent" class="show-nav-link">MacGyver Classic</a></li><li class="show-list-item"><a href="/shows/madam-secretary/" target="_parent" class="show-nav-link">Madam Secretary</a></li><li class="show-list-item"><a href="/shows/medium/" target="_parent" class="show-nav-link">Medium</a></li><li class="show-list-item"><a href="/shows/melrose_place/" target="_parent" class="show-nav-link">Melrose Place</a></li><li class="show-list-item"><a href="/shows/mission-impossible/" target="_parent" class="show-nav-link">Mission Impossible</a></li><li class="show-list-item"><a href="/shows/nash-bridges/" target="_parent" class="show-nav-link">Nash Bridges</a></li><li class="show-list-item"><a href="/shows/ncis/" target="_parent" class="show-nav-link">NCIS</a></li><li class="show-list-item"><a href="/shows/ncis_los_angeles/" target="_parent" class="show-nav-li ...
#     </ul>
# </div>
#
# <div class="left leftContainer">
#     <div class="section cm">
#         <h4>Comedy</h4>
#         <ul class="menu-section-items comedy">
#             <li class="show-list-item"><a href="/shows/2_broke_girls/" target="_parent" class="show-nav-link">2 Broke Girls</a></li><li class="show-list-item"><a href="/shows/angel-from-hell/" target="_parent" class="show-nav-link">Angel From Hell</a></li><li class="show-list-item"><a href="/shows/big_bang_theory/" target="_parent" class="show-nav-link">The Big Bang Theory</a></li><li class="show-list-item"><a href="/shows/the_brady_bunch/" target="_parent" class="show-nav-link">The Brady Brunch</a></li><li class="show-list-item"><a href="/shows/caroline-in-the-city/" target="_parent" class="show-nav-link">Caroline in the City</a></li><li class="show-list-item"><a href="/shows/cheers/" target="_parent" class="show-nav-link">Cheers</a></li><li class="show-list-item"><a href="/shows/everybody_hates_chris/" target="_parent" class="show-nav-link">Everybody Hates Chris</a></li><li class="show-list-item"><a href="/shows/family_ties/" target="_parent" class="show-nav-link">Family Ties</a></li><li class="show-list-item"><a href="/shows/frasier/" target="_parent" class="show-nav-link">Frasier</a></li><li class="show-list-item"><a href="/shows/the-great-indoors/" target="_parent" class="show-nav-link">The Great Indoors</a></li><li class="show-list-item"><a href="/shows/i_love_lucy/" target="_parent" class="show-nav-link">I Love Lucy</a></li><li class="show-list-item"><a href="/shows/kevin-can-wait/" target="_parent" class="show-nav-link">Kevin Can Wait</a></li><li class="show-list-item"><a href="/shows/life-in-pieces/" target="_parent" class="show-nav-link">Life in Pieces</a></li><li class="show-list-item"><a href="/shows/man-with-a-plan/" target="_parent" class="show-nav-link">Man With A Plan</a></li><li class="show-list-item"><a href="/the-millers/" target="_parent" class="show-nav-link">The Millers</a></li><li class="show-list-item"><a href="/shows/mom/" target="_parent" class="show-nav-link">Mom</a></li><li class="show-list-item"><a href="/shows/the-odd-couple/" target="_parent" class="show-nav-link">The Odd Couple</a></li><li class="show-list-item"><a href="/shows/the-odd-couple-classic/" target="_parent" class="show-nav-link">The Odd Couple Classic</a></li><li class="show-list-item"><a href="/shows/sabrina-the-teenage-witch/" target="_parent" class="show-nav-link">Sabrina The Teenage Witch</a></li><li class="show-list-item"><a href="/shows/taxi/" target="_parent" class="show-nav-link">Taxi</a></li><li class="show-list-item"><a href="/shows/wings/" target="_parent" class="show-nav-link">Wings</a></li>
#         </ul>
#     </div>
#     <div class="left dt">
#         <div class="section">
#             <h4>Daytime</h4>
#             <ul class="menu-section-items">
#                 <li class="show-list-item"><a href="/shows/the_bold_and_the_beautiful/" target="_parent" class="show-nav-link">The Bold and the Beautiful</a></li><li class="show-list-item"><a href="/shows/lets_make_a_deal/" target="_parent" class="show-nav-link">Let's Make a Deal</a></li><li class="show-list-item"><a href="/shows/the_price_is_right/" target="_parent" class="show-nav-link">The Price Is Right</a></li><li class="show-list-item"><a href="/shows/the_talk/" target="_parent" class="show-nav-link">The Talk</a></li><li class="show-list-item"><a href="/shows/the_young_and_the_restless/" target="_parent" class="show-nav-link">The Young and the Restless</a></li><li class="show-list-item"><a href="/shows/cbs-dream-team/" target="_parent" class="show-nav-link">The CBS Dream Team...It's Epic</a></li>
#             </ul>
#         </div>
#     </div>
#     <div class="left ms">
#         <div class="section">
#             <h4>Movies & Specials</h4>
#             <ul class="menu-section-items specials">
#                 <li class="show-list-item"><a href="/shows/academy_of_country_music/" target="_parent" class="show-nav-link">Academy of Country Music Awards</a></li><li class="show-list-item"><a href="/shows/acm-honors/" target="_parent" class="show-nav-link">ACM Honors</a></li><li class="show-list-item"><a href="/cbs_cares/" target="_parent" class="show-nav-link">CBS Cares</a></li><li class="show-list-item"><a href="/shows/cbs-fall-premieres-2016/" target="_parent" class="show-nav-link">Fall Premieres 2016</a></li><li class="show-list-item"><a href="/shows/grammys/" target="_parent" class="show-nav-link">GRAMMY® Awards</a></li><li class="show-list-item"><a href="/shows/peoples_choice_awards/" target="_parent" class="show-nav-link">People's Choice Awards</a></li><li class="show-list-item"><a href="/shows/stand-up-to-cancer/" target="_parent" class="show-nav-link">Stand Up To Cancer</a></li><li class="show-list-item"><a href="/shows/tony_awards/" target="_parent" class="show-nav-link">Tony ® Awards</a></li><li class="show-list-item"><a href="/shows/victorias_secret/" target="_parent" class="show-nav-link">Victoria's Secret Fashion Show</a></li><li class="show-list-item"><a href="/shows/watch_magazine/" target="_parent" class="show-nav-link">Watch! Magazine</a></li>
#             </ul>
#         </div>
#     </div>
#     <div class="clear"></div>
# </div>
# <div class="left">
#     <div class="section rtmsc">
#         <h4>Reality</h4>
#         <div class="content">
#             <ul class="menu-section-items"><li class="show-list-item"><a href="/shows/amazing_race/" target="_parent" class="show-nav-link">The Amazing Race</a></li><li class="show-list-item"><a href="/shows/big_brother/" target="_parent" class="show-nav-link">Big Brother</a></li><li class="show-list-item"><a href="/shows/big-brother-over-the-top/" target="_parent" class="show-nav-link">Big Brother: Over the Top</a></li><li class="show-list-item"><a href="/shows/the-case-of-jonbenet-ramsey/" target="_parent" class="show-nav-link">The Case Of: JonBenét Ramsey</a></li><li class="show-list-item"><a href="/shows/survivor/" target="_parent" class="show-nav-link">SURVIVOR™</a></li><li class="show-list-item"><a href="/shows/undercover_boss/" target="_parent" class="show-nav-link">Undercover Boss</a></li></ul>
#         </div>
#     </div>
#     <div class="section rtmsc">
#         <h4>Late Night</h4>
#         <div class="content">
#             <ul class="menu-section-items"><li class="show-list-item"><a href="/shows/the-late-show-with-stephen-colbert/" target="_parent" class="show-nav-link">The Late Show with Stephen Colbert</a></li><li class="show-list-item"><a href="/shows/late-late-show/" target="_parent" class="show-nav-link">The Late Late Show with James Corden</a></li></ul>
#         </div>
#     </div>
#     <div class="section rtmsc">
#         <h4>News & Sports</h4>
#         <div class="content">
#             <ul class="menu-section-items"><li class="show-list-item"><a href="/shows/48_hours/" target="_parent" class="show-nav-link">48 Hours</a></li><li class="show-list-item"><a href="/shows/60_minutes/" target="_parent" class="show-nav-link">60 Minutes</a></li><li class="show-list-item"><a href="/shows/cbs_evening_news/" target="_parent" class="show-nav-link">CBS Evening News</a></li><li class="show-list-item"><a href="http://www.cbssports.com/" target="_parent" class="show-nav-link">CBS Sports</a></li><li class="show-list-item"><a href="/shows/cbs_this_morning/" target="_parent" class="show-nav-link">CBS This Morning</a></li><li class="show-list-item"><a href="/shows/face-the-nation/" target="_parent" class="show-nav-link">Face the Nation</a></li><li class="show-list-item"><a href="/superbowl/" target="_parent" class="show-nav-link">Super Bowl on CBS</a></li></ul>
#         </div>
#     </div>
# </div>
# <div class="clear"></div>                                    </div>
#                                 </section>
#
#                             </div>
#                         </div>
#                     </div>
#
#                     <a href="/watch" data-role="main-nav-item"
#                        class="">FULL EPISODES</a>
#                     <a href="/live-tv/" data-role="main-nav-item"
#                        class="">LIVE TV</a>
#                     <a href="/schedule/" data-role="main-nav-item"
#                        class="">SCHEDULE</a>
#                     <section id="globalNavMore">
#
#                         <div class='navItem' id='globalMoreButton'> MORE</div>
#
#                         <ul>
#                             <li><a href="http://cbs.seenon.com/?ecid=PRF-CBS-300115&PA=PRF-CBS-300115"
#                                    data-role="main-nav-item"> SHOP</a></li>
#                             <li><a href="/user/mycbs" data-role="main-nav-item"> MY CBS </a></li>
#                             <li><a href="http://cbsnews.com" data-role="main-nav-item"> CBS NEWS </a></li>
#                             <li><a href="http://cbssports.com" data-role="main-nav-item"> CBS SPORTS </a></li>
#                         </ul>
#
#                     </section>
#                 </nav>
#                 <div class="_s_ left"></div>
#
#                 <div id="globalSearch" class="left">
#                     <a href="javascript:void(0);"></a>
#                 </div>
#
#                                 <div id="globalUserBar" class="right ">
#                     <div id="globalBarUserLink" onclick="GlobalLogin.showLogin(event, this, true); ">
#                         <span id="userBarName">SIGN IN</span>
#                         <span id="userBarArrow"></span>
#                     </div>
#
#
#                                         <a href="/all-access/?intcid=CIAb4ac575" class="left aa-btn "
#                         >
#                         Try CBS All Access                    </a>
#
#                 </div>
#                             </div>
#         </div>
#     </section>
#
# </header> <!-- End of #globalHeaderContainer -->
# <!-- search -->
# <div id="globalSearchBox">
#     <section class="widthWrapper">
#         <div class="lrGutter">
#             <div class="header">
#                 <div></div>
#                 <div>Search</div>
#                 <a href="javascript:void(0);" class="close"></a>
#             </div>
#             <input type="search" id='ui-site-search-box'>
#
#             <div class="autoCompleteRes"></div>
#         </div>
#     </section>
# </div>
# <!-- end search -->
# <script>
#     var CBSHeader = null;
#     var GlobalLogin;
#
#     $(document).ready(function () {
#         CBSHeader = new CBS.Header();
#
#         CBSHeader.init();
#         GlobalLogin = new Login("loginModal");
#     });
#
# </script>
#     <link rel="stylesheet" href="http://wwwimage.cbsstatic.com/assets/min/css/shows/show_header.min.css?20161028-233225">
#     <link rel="stylesheet" href="http://wwwimage.cbsstatic.com/assets/min/css/shows/showHeaderOffset.min.css?20161028-233225">     <div id='globalShowHeader' class="showHeader">
#         <section class="widthWrapper">
#             <div class="lrGutter">
#
#                                     <a href="/shows/amazing_race/" class="show-title">The Amazing Race <div id="showTitleDivider"> </div> </a>
#
#                 <ul class='menuItems'>
#
#                                                     <li>
#
#                                                                         <a class="" href="/shows/amazing_race/"> Home </a>
#                                                                 </li>
#
#                                                     <li>
#
#                                                                         <a class="active" href="/shows/amazing_race/video/"> Full Episodes </a>
#                                                                 </li>
#
#                                                     <li>
#
#                                                                         <a class="" href="/shows/amazing_race/photos/"> Photos </a>
#                                                                 </li>
#
#                                                     <li>
#
#                                                                         <a class="" href="/shows/amazing_race/shop/"> Shop </a>
#                                                                 </li>
#
#                                                     <li class="moreMenuItems">
#                                 <div> More </div>
#                                 <ul>
#                                                                             <li>
#                                                                                             <a class="" href="/shows/amazing_race/about/"> About </a>
#                                                                                     </li>
#                                                                             <li>
#                                                                                             <a class="" href="/shows/amazing_race/cast/"> Cast </a>
#                                                                                     </li>
#                                                                             <li>
#                                                                                             <a class="" href="/shows/amazing_race/elimination_interviews/"> Elimination Interviews </a>
#                                                                                     </li>
#                                                                             <li>
#                                                                                             <a class="" href="/shows/amazing_race/episodes/"> Episodes </a>
#                                                                                     </li>
#                                                                             <li>
#                                                                                             <a class="" href="/shows/amazing_race/news/"> News </a>
#                                                                                     </li>
#                                                                             <li>
#                                                                                             <a class="" href="/shows/amazing_race/news/1001785/"> Winners List </a>
#                                                                                     </li>
#                                                                     </ul>
#                             </li>
#                                                             </ul>
#
#                 <div class="tune-info right">
#                     Returns for Season 29                </div>
#             </div>
#         </section>
#     </div>
# <script src='/assets/min/js/show/show_header.min.js?20161028-233225'></script>
# <script>
#     var ShowHeader; //Should be declared globally.
#     $(document).ready(function () {
#         ShowHeader = new ShowHeaderModule("globalShowHeader");
#     });
#
# </script>
#             <div id="masterPageWrapper"><!-- ad skin is applied to this div -->
#
#                 <div id="skin-top">
#
#                 </div>
#
#                 <div id="secondaryPageWrapper"><!-- page shadow is applied to this div -->
#
#
#                     <div id="stickyheader">
#                         <div id="substickyheader">
#                             <div id="show_nav_stick">
#                                                             </div>
#                         </div>
#                     </div>
#
#                     <div class="clear"></div>
#
#                                         <div id="cbs-show-page">
#                                                 <div id="adSkinLeft"></div>
# <div id="adSkinRight"></div>
#
#
# <div id="stickyAds" style="position: relative">
#     <style>
# div#cbs-pushdown-wrapper {
# 	position:relative;
# 	text-align:center;
# 	width:970px;
# 	margin:0 auto;
# }
#
# div#masterTopWrapper {background-position:bottom !important}
# div#masterPageWrapper {zoom:1}
# </style>
#
# <div id="cbs-pushdown-wrapper">
# 	<div id="leader-plus-top"></div>
# </div>
#
# <!--[if lte IE 7]>
# <script language="javascript" type="text/javascript">
# 	function ieRedrawFixCollapsed () {
# 		jQuery(".cbs-mod-rc").css({position: 'relative'});
# 		jQuery(".cbs-mod-rc-2x").css({position: 'relative'});
# 		jQuery(".playBtnOverlay").css({position: 'relative'});
# 	}
# 	function ieRedrawFixExpanded () {
# 		jQuery(".cbs-mod-rc").css({position: 'static'});
# 		jQuery(".cbs-mod-rc-2x").css({position: 'static'});
# 		jQuery(".playBtnOverlay").css({position: 'static'});
# 	}
# </script>
# <![endif]-->
#
#
# 	    </div>
#
#                         <style>
#     div#masterPageWrapper {
#         background: #fff none repeat scroll 0 center;
#     }
#     div.video-background-wrapper {
#         background-color: #000;
#         width: 100%;
#         overflow: visible;
#     }
#     div.cbs-show-mod-featured.video-wrapper {
#         background-color: #000;
#         text-align: left;
#         padding-bottom: 30px;
#         padding-top: 18px;
#         overflow: visible;
#         margin: 0 auto;
#         width: 888px;
#     }
#
#     .player-problems-link {
#         color: #bebebe;
#         position: absolute;
#         right: 0;
#         top: -20px;
#         cursor: pointer;
#     }
#
#     .player-problems-link:hover {
#         text-decoration: none;
#     }
#
#     div#player-wrapper {
#         position: relative;
#         margin: 20px 20px 0;
#     }
#
#     .yahwidRecommended {
#         padding-left:0;
#         padding-right: 0;
#     }
#
#     .cbs-show-content-wrapper .video-carousel-box {margin:0 !important;}
#     h2.video-section-title {margin-left:0}
#
#
#
#     div#cbs-show-page {
#        margin-top: 0 !important;
#     }
#     div#substickyheader {
#        position: relative;
#     }
#
# </style>
#
#
#
#
#
#
#
# <div class="video-background-wrapper">
#     <div class="cbs-show-mod-featured video-wrapper ">
#
#
#
#                             <!-- We are in the denied condition, and are using the denied player template -->
#                 <div id="player-wrapper">    <div id="centeredPlayerContainer"></div>     <div id="ad985x90"></div>
#     <div id="cbs-share-wrapper"></div>
#     <div id="flashcontent">
#         <div id="VIDEO_CONTENT">
#             <div id="svod-video-outerlay">
#
#     <div id="bg-img">
#         <img src="http://wwwimage5.cbsstatic.com/thumbnails/videos/w848/CBS_Production_Entertainment_VMS/2014/08/03/314615364002/CBS_AMAZING_RACE_101_CONTENT_CIAN_NY_369206_1296_1280x720_324694595831_407636_640x360.jpg" width="848px" height="477"/>
#     </div>
#
#     <div id="bg-mask"></div>
#
#     <div id="svod-video-overlay">
#
#         <div id="svod-video-upsell-header"></div>
#
#                     <div class="sub vid-main-upsell-copy"></div>
#
#
#             <div class="width100pct floatLeft marginTop20px">
#                                 <a href="/all-access/play/Hm5mwvw448X3RjQVdxVGTIUM4GhOjcfh/?intcid=CIA50c5bed" class="ui-try-button-vid width248px vid-upsell-cta"></a>
#                             </div>
#
#
#                 Already have CBS All Access? <a href="javascript:void(0)" id="lnk-video-upsell-login" onclick="GlobalLogin.showLogin(event, this);">Sign In</a>
#
#     </div>
# </div>
#
# <script type="text/javascript">
#
#     var prt = $('#svod-video-overlay');
#     prt.find('.vid-main-upsell-copy').html("You must be a CBS All Access subscriber to enjoy this video. <br \/>\r\n\r\nTry it now and get 1 Week FREE.<br \/>\r\n\r\n");
#     prt.find('.vid-upsell-cta').html("Learn More");
# </script>
#
#
# <style>
#     #svod-video-outerlay {
#         background-color: #000;
#         float: left;
#         height: 477px;
#         position: relative;
#         width: 848px;
#         z-index: 1;
#     }
#
#     #svod-video-outerlay a:hover {
#         text-decoration: none;
#     }
#
#     #bg-img {
#         position: absolute;
#         width: 848px;
#         height: 477px;
#     }
#
#     #bg-mask {
#         position: absolute;
#         width: 848px;
#         height: 477px;
#         background-color: #000;
#         opacity: .8;
#     }
#
#     #svod-video-overlay {
#         font-family: "Arial";
#         height: 477px;
#         position: absolute;
#         width: 848px;
#         color: #fff;
#         font-size: 18px;
#         text-align: center;
#     }
#
#     #svod-video-overlay .sub {
#         float: left;
#         font-size: 28px;
#         line-height: 38px;
#         font-weight: 100;
#         float: left;
#         width: 100%;
#     }
#
#     a.ui-try-button-vid {
#         background-color: #22578e;
#         display: block;
#         color: #fff;
#         text-align: center;
#         height: 42px;
#         line-height: 51px;
#         text-align: center;
#         font-weight: normal;
#         font-size: 24px;
#         margin: 0px auto 20px 260px;
#         float: left;
#         width: 329px;
#         height: 52px;
#         padding: 0;
#     }
#
#     #svod-video-upsell-header {
#         background: url("/assets/images/svod/v2/svod-sprite.png") no-repeat scroll -1px -234px rgba(0, 0, 0, 0);
#         height: 56px;
#         margin: 65px auto 25px;
#         width: 594px;
#     }
#
#     .width104px {
#         width: 104px;
#     }
#
#     .width100pct {
#         width: 100%;
#     }
#
#     .width248px {
#         width: 248px;
#     }
#
#     .marginTop20px {
#         margin-top: 20px;
#     }
#
#     .marginL372px {
#         margin-left: 372px;
#     }
#
#     .marginBot40 {
#         margin-bottom: 40px;
#     }
#
#     .wf-active #svod-video-overlay, .wf-active #svod-video-overlay .sub {
#         font-family: "Lato";
#     }
# </style>        </div>
#
#     </div>
#
#     <div id="ad985x130"></div>
#
#     <div id="video-info-wrapper">
#
#                                     <div>
#                     <div id="ad300x60"></div>
#
#                     <div id="cbs-xfp-300x60" style="display:none">
#                         <script type="text/javascript">
#                             googletag.cmd.push(function() {
#                                 googletag.display('cbs-xfp-300x60');
#                             });
#                         </script>
#                     </div>
#
#                     <div class="video-metadata">
#                         The Amazing Race                        <div class="title">The Race Begins <span>S1 Ep1 (44:21)</span></div>
#                     </div>
#                     <div class="clear"></div>
#                 </div>
#                 <div class="video-social">
#                     <ul class="cbs-social-btns">
#                         <li class="fb"><a class="fb btn facebook-like" data-send="false" data-layout="button_count" data-href="http://www.cbs.com/shows/amazing_race/video/">Like</a></li>
#                         <li class="tw"><a class="tw btn twitter-share" href="http://twitter.com/share" data-url="http://www.cbs.com/shows/amazing_race/video/">Tweet</a></li>
#                         <li class="gp"><a class="gp btn googleplus-one" data-size="medium" data-href="http://www.cbs.com/shows/amazing_race/video/">Share</a></li>
#                                                 <li class="by"><a href="javascript:;" class="by" id="id-video-buy">Buy</a>
#                                                             <div id="buy-tip" class="cbs-box-wrapper box-account-wrapper">
#                                     <div class="box-arrow-up"></div>
#                                     <div class="cbs-box">
#                                         <div class="head">
#                                             <div class="gutter"><h2>Get Episode</h2>
#
#                                                 <div class="close"></div>
#                                                 <div class="clear"></div>
#                                             </div>
#                                         </div>
#                                         <div class="body">
#                                             <div class="gutter buy-btns">
#                                                 <!-- These are the buy links -->
#                                                                                                         <a href="http://bit.ly/X8PXvf" class="itunes" target="_blank">itunes</a>
#                                                                                                             <a href="http://amzn.to/Xqy2jt" class="amazon" target="_blank">amazon</a>
#                                                                                                             <a href="http://bit.ly/1BMVB5o" class="vudu" target="_blank">vudu</a>
#
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#                                                     </li>
#                                                 <li class="if"><a class="if btn" href="javascript:;" class="if" id="id-video-info">Info</a>
#                                                             <div id="info-tip" class="cbs-box-wrapper box-account-wrapper">
#                                     <div class="box-arrow-up"></div>
#                                     <div class="cbs-box">
#                                         <div class="head">
#                                             <div class="gutter"><h2>About This Video</h2>
#
#                                                 <div class="close"></div>
#                                                 <div class="clear"></div>
#                                             </div>
#                                         </div>
#                                         <div class="body">
#                                             <div class="gutter buy-btns">
#
#                                                 <div class="bold">The Amazing Race - The Race Begins</div>
#                                                 <div class="airdate">Air Date: 09/05/01</div>
#                                                 <div></div>
#
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#
#                                                     </li>
#                         <li class="cn">
#                             <div class="cbs-checkin-holder">
#                                 <div class="cbs-checkin-button" data-content="Hm5mwvw448X3RjQVdxVGTIUM4GhOjcfh" data-id="21028"></div>
#                             </div>
#                         </li>
#                     </ul>
#                 </div>
#
#     </div>
#
#
#     <script language="javascript" type="text/javascript">
#                 var video = new CBS.Video();
#         video.settings.show_id = 21028;
#         video.settings.content_id = 'Hm5mwvw448X3RjQVdxVGTIUM4GhOjcfh';
#         video.settings.tms_program_id = '';
#         video.settings.title = "The Amazing Race - The Race Begins";
#         video.settings.width = '100%';
#         video.settings.height = '100%';
#         video.settings.container = 'VIDEO_CONTENT';
#         video.settings.related_videos = true;
#
#         video.settings.preview_image = "http://thumbnails.cbsig.net/CBS_Production_Entertainment_VMS/2014/08/03/314615364002/CBS_AMAZING_RACE_101_CONTENT_CIAN_NY_369206_1296_1280x720_324694595831_407636_640x360.jpg";
#         video.settings.xfp = true;
#         video.page_options = {};
#         video.page_options.share_url = "http://www.cbs.com/shows/amazing_race/video/";
#         video.page_options.base_url_video = "\/shows\/amazing_race\/";
#
#         video.section_ids = [238047,240805,238879];
# ...
#             if (marquee_top) adChunk1.push(adSlots['marquee_top']);
#             if (mpu_top) {
#                 adChunk1.push(adSlots['mpu_top']);
#             }
#             if (mpu_plus_top) adChunk1.push(adSlots['mpu_plus_top']);
#             if (skin_top) adChunk1.push(adSlots['skin_top']);
#             if (leader_middle) adChunk1.push(adSlots['leader_middle']);
#             if (magnet_bottom) adChunk1.push(adSlots['magnet_bottom']);
#             if (mpu_bottom) adChunk2.push(adSlots['mpu_bottom']);
#             if (leader_bottom) adChunk2.push(adSlots['leader_bottom']);
#
#             if(adChunk1.length>0) googletag.pubads().refresh(adChunk1);
#         }
#
#
#     });
#     */
#
#     //IX integration
#     googletag.cmd.push(function () {
#
#         if (disableInitialLoadFlag) {
#
#             adChunk1.push(adSlots['sharethrough']);
#
#             if (prestitial) {
#                 adChunk1.push(adSlots['prestitial']);
#             }
#
#             if (interstitial) {
#                 adChunk1.push(adSlots['interstitial']);
#             }
#             if (native_top) {
#                 adChunk1.push(adSlots['native_top']);
#             }
#             if (leader_top) adChunk1.push(adSlots['leader_top']);
#             if (leader_plus_top) adChunk1.push(adSlots['leader_plus_top']);
#             if (marquee_top) adChunk1.push(adSlots['marquee_top']);
#             if (mpu_top) {
#                 adChunk1.push(adSlots['mpu_top']);
#             }
#             if (mpu_plus_top) adChunk1.push(adSlots['mpu_plus_top']);
#             if (skin_top) adChunk1.push(adSlots['skin_top']);
#             if (leader_middle) adChunk1.push(adSlots['leader_middle']);
#             if (magnet_bottom) adChunk1.push(adSlots['magnet_bottom']);
#             if (mpu_bottom) adChunk2.push(adSlots['mpu_bottom']);
#             if (leader_bottom) adChunk2.push(adSlots['leader_bottom']);
#
#         }
#
#         if(typeof index_headertag_lightspeed !== 'undefined') {
#             index_headertag_lightspeed.add_session_end_hook((function (chunk) {
#                 return function() {
#                     var slots = googletag.pubads().getSlots();
#                     index_headertag_lightspeed.set_slot_targeting(slots);
#                     if(chunk.length>0) googletag.pubads().refresh(chunk);
#                 };
#             })(adChunk1), true);
#             index_headertag_lightspeed.refresh();
#         } else {
#             if(adChunk1.length>0) googletag.pubads().refresh(adChunk1);
#         }
#
#     });
#
#     /*
#
#     if (prestitial) googletag.cmd.push(function() {googletag.display(prestitial_id);});
#     if (interstitial) googletag.cmd.push(function() {googletag.display(interstitial_id);});
#     if (leader_top) googletag.cmd.push(function() { googletag.display(leader_top_id);});
#     if (leader_plus_top) googletag.cmd.push(function() { googletag.display(leader_plus_top_id);});
#     if (marquee_top) googletag.cmd.push(function() { googletag.display(marquee_top_id);});
#     if (mpu_top) googletag.cmd.push(function() { googletag.display(mpu_top_id);});
#     if (mpu_plus_top) googletag.cmd.push(function() { googletag.display(mpu_plus_top_id);});
#     if (skin_top) googletag.cmd.push(function() {googletag.display(skin_top_id);});
#
#     if (leader_middle) googletag.cmd.push(function() { googletag.display(leader_middle_id);});
#     if (magnet_bottom) googletag.cmd.push(function() {googletag.display(magnet_bottom_id);});
#
#     if (mpu_bottom) googletag.cmd.push(function() { googletag.display(mpu_bottom_id);});
#     if (leader_bottom) googletag.cmd.push(function() { googletag.display(leader_bottom_id);});
#
#     if (native_top) googletag.cmd.push(function() {googletag.display(native_top_id);});
# */
#     //IX integration
#     if(typeof index_headertag_lightspeed !== 'undefined') {
#         googletag.cmd.push(function () {
#             index_headertag_lightspeed.add_session_end_hook(function () {
#                 var slots = googletag.pubads().getSlots();
#                 index_headertag_lightspeed.set_slot_targeting(slots);
#                 if (prestitial) googletag.cmd.push(function () {googletag.display(prestitial_id);});
#                 if (interstitial) googletag.cmd.push(function () {googletag.display(interstitial_id);});
#                 if (leader_top) googletag.cmd.push(function () {googletag.display(leader_top_id);});
#                 if (leader_plus_top) googletag.cmd.push(function () {googletag.display(leader_plus_top_id);});
#                 if (marquee_top) googletag.cmd.push(function () {googletag.display(marquee_top_id);});
#                 if (mpu_top) googletag.cmd.push(function () {googletag.display(mpu_top_id);});
#                 if (mpu_plus_top) googletag.cmd.push(function () {googletag.display(mpu_plus_top_id);});
#                 if (skin_top) googletag.cmd.push(function () {googletag.display(skin_top_id);});
#                 if (leader_middle) googletag.cmd.push(function () {googletag.display(leader_middle_id);});
#                 if (magnet_bottom) googletag.cmd.push(function () {googletag.display(magnet_bottom_id);});
#                 if (mpu_bottom) googletag.cmd.push(function () {googletag.display(mpu_bottom_id);});
#                 if (leader_bottom) googletag.cmd.push(function () {googletag.display(leader_bottom_id);});
#                 if (native_top) googletag.cmd.push(function () {googletag.display(native_top_id);});
#             }, true);
#             index_headertag_lightspeed.refresh();
#         });
#     } else {
#         if (prestitial) googletag.cmd.push(function () {googletag.display(prestitial_id);});
#         if (interstitial) googletag.cmd.push(function () {googletag.display(interstitial_id);});
#         if (leader_top) googletag.cmd.push(function () {googletag.display(leader_top_id);});
#         if (leader_plus_top) googletag.cmd.push(function () {googletag.display(leader_plus_top_id);});
#         if (marquee_top) googletag.cmd.push(function () {googletag.display(marquee_top_id);});
#         if (mpu_top) googletag.cmd.push(function () {googletag.display(mpu_top_id);});
#         if (mpu_plus_top) googletag.cmd.push(function () {googletag.display(mpu_plus_top_id);});
#         if (skin_top) googletag.cmd.push(function () {googletag.display(skin_top_id);});
#         if (leader_middle) googletag.cmd.push(function () {googletag.display(leader_middle_id);});
#         if (magnet_bottom) googletag.cmd.push(function () {googletag.display(magnet_bottom_id);});
#         if (mpu_bottom) googletag.cmd.push(function () {googletag.display(mpu_bottom_id);});
#         if (leader_bottom) googletag.cmd.push(function () {googletag.display(leader_bottom_id);});
#         if (native_top) googletag.cmd.push(function () {googletag.display(native_top_id);});
#     }
#
# /*
#
#     googletag.cmd.push(function () {
#         if (isSpecialPage) {
#             if (adChunk2.length > 0) {
#                 googletag.pubads().refresh(adChunk2);
#                 adChunk2 = [];
#             }
#         }
#     });
# */
#
#     //IX integration
#     googletag.cmd.push(function () {
#         if (isSpecialPage) {
#             if (adChunk2.length > 0) {
#                 if(typeof index_headertag_lightspeed !== 'undefined') {
#                     index_headertag_lightspeed.add_session_end_hook((function (chunk) {
#                         return function() {
#                             var slots = googletag.pubads().getSlots();
#                             index_headertag_lightspeed.set_slot_targeting(slots);
#                             googletag.pubads().refresh(chunk);
#                         };
#                     })(adChunk2), true);
#                     index_headertag_lightspeed.refresh();
#                 } else {
#                     googletag.pubads().refresh(adChunk2);
#                 }
#                 adChunk2 = [];
#             }
#         }
#     });
#
#
#
#
#     googletag.cmd.push(function () {
#         /*
#         if (typeof adChunk4 != 'undefined' && adChunk4.length > 0) {
#             //googletag.pubads().refresh(adChunk4);
#             //adChunk4 = [];
#         }
#         */
#
#         //IX integration
#         if (typeof adChunk4 != 'undefined' && adChunk4.length > 0) {
#             if (typeof index_headertag_lightspeed !== 'undefined') {
#                 index_headertag_lightspeed.add_session_end_hook((function (chunk) {
#                     return function () {
#                         var slots = googletag.pubads().getSlots();
#                         index_headertag_lightspeed.set_slot_targeting(slots);
#                         googletag.pubads().refresh(chunk);
#                     };
#                 })(adChunk4), true);
#                 index_headertag_lightspeed.refresh();
#             } else {
#                 googletag.pubads().refresh(adChunk4);
#             }
#             adChunk4 = [];
#         }
#     });
#
#     _enableBeanstock = false; //turning off beanstock permanently
#
#     if (_enableBeanstock) {
#         var _adCallsFired = false;
#         function fireAdCallNucleusCompleteHandler() {
#             setTimeout(function () {
#                 CBS.Registry.ads = {beanstock: true};
#                 var _ad_chunks = $.extend({}, adChunk1, adChunk2);
#
#                 googletag.cmd.push(function () {
#                     googletag.pubads().refresh(_ad_chunks);
#
#                 });
#             }, 1000);
#         }
#
#         (function() {
#             var bsm_nucleus = document.createElement("script");
#             bsm_nucleus.async = true;
#             bsm_nucleus.type = "text/javascript";
#             var useSSL = "https:" == document.location.protocol;
#             bsm_nucleus.id = 'cx-nuke';
#             bsm_nucleus.src = (useSSL ? "https:" : "http:") + "//cdn.beanstock.com/pub/cx/flagTag.js";
#             bsm_nucleus.setAttribute('data-bsm-pub', "cbsinteractive");
#             bsm_nucleus.setAttribute('data-bsm-pub-zone', "cbs.com/nucleus");
#             bsm_nucleus.setAttribute('data-bsm-sizes', "728x90 300x250 320x50");
#             bsm_nucleus.setAttribute('data-bsm-zone-map-url', "//cdn.beanstock.com/pub/cbsinteractive/zm.js");
#             bsm_nucleus.setAttribute('data-bsm-event-host', "//helix.beanstock.co");
#             bsm_nucleus.setAttribute('data-bsm-flag', "true");
#             bsm_nucleus.setAttribute('data-bsm-version', "v3");
#             bsm_nucleus.addEventListener("onNucleusComplete", fireAdCallNucleusCompleteHandler);
#             var node = document.getElementsByTagName("script")[0];
#             node.parentNode.insertBefore(bsm_nucleus, node);
#         })();
#
#
#     }
#
# </script>
#
# <style>
#     body.skinAd div.cbs-show-content-right {width: 300px;}
#     div#stickyAds{z-index: 2 !important;}
#     div#cbs-show-page{overflow: hidden !important;}
#     div#masterPageWrapper {display: block !important}
#     iframe[width="1600"]{display: none}
#     div#leader-plus-top {padding: 10px 0 }
#     div#leader-plus-top:empty, div#leader-top:empty { padding:0 }
#     div#leader-middle {padding-top: 10px }
#     div#leader-middle:empty { padding-top:0 }
#     div#leader-top > div, div#leader-top > div > table, div#leader-top > div > div, div#leader-top > div > iframe {text-align: center; margin: 0 auto !important}
#     div#leader-plus-top > div > table, div#leader-plus-top > div > div, div#leader-plus-top > div > iframe {text-align: center; margin: 0 auto !important}
# </style>
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"TVEpisode","@id":"Hm5mwvw448X3RjQVdxVGTIUM4GhOjcfh","name":"The Race Begins","description":"","url":"http://www.cbs.com/shows/amazing_race/video/Hm5mwvw448X3RjQVdxVGTIUM4GhOjcfh/the-amazing-race-the-race-begins/","image":"http://thumbnails.cbsig.net/CBS_Production_Entertainment_VMS/2014/08/03/314615364002/CBS_AMAZING_RACE_101_CONTENT_CIAN_NY_369206_1296_1280x720_324694595831_407636_640x360.jpg","episodeNumber":"1","partOfSeason":{"@type":"TVSeason","seasonNumber":"1"},"partOfSeries":{"@type":"TVSeries","name":"The Amazing Race","sameAs":"http://www.imdb.com/title/tt0285335/"},"releasedEvent":{"@type":"PublicationEvent","startDate":"2001-09-05T20:00:00-07:00","location":{"@type":"Country","name":"US"}},"potentialAction":[{"@type":"WatchAction","target":{"@type":"EntryPoint","urlTemplate":"http://www.cbs.com/shows/amazing_race/video/Hm5mwvw448X3RjQVdxVGTIUM4GhOjcfh/the-amazing-race-the-race-begins/","actionPlatform":"http://schema.org/DesktopWebPlatform"},"expectsAcceptanceOf":[{"@type":"Offer","category":"free","availabilityStarts":"2001-09-05T20:00:00-07:00","availabilityEnds":"2400-12-22T00:00:00-0800","eligibleRegion":{"@type":"Country","name":"US"}}]},{"@type":"WatchAction","target":{"@type":"EntryPoint","urlTemplate":"android-app://com.cbs.app/cbs/http://www.cbs.com/shows/amazing_race/video/Hm5mwvw448X3RjQVdxVGTIUM4GhOjcfh/the-amazing-race-the-race-begins/?campaign=ftag:ADLbe6cacd&fg=1","actionPlatform":"http://schema.org/AndroidPlatform"},"expectsAcceptanceOf":[{"@type":"Offer","category":"free","availabilityStarts":"2014-10-15T00:00:00-0700","availabilityEnds":"2400-12-22T00:00:00-0800","eligibleRegion":{"@type":"Country","name":"US"}}]},{"@type":"WatchAction","target":{"@type":"EntryPoint","urlTemplate":"http://www.cbs.com/shows/amazing_race/video/Hm5mwvw448X3RjQVdxVGTIUM4GhOjcfh/","actionPlatform":"http://schema.org/IOSPlatform"},"expectsAcceptanceOf":[{"@type":"Offer","category":"free","availabilityStarts":"2014-10-15T00:00:00-0700","availabilityEnds":"2400-12-22T00:00:00-0800","eligibleRegion":{"@type":"Country","name":"US"}}]}]}</script>
#
#                     </div>
#                 </div>
#             </div>
#                             <script type="text/JavaScript">
#                     <!--
#                     cbsiSetupAdDiv("ads_magnet", cbsiad266_100);                    cbsiGetDeferredAds(["ad728x90", "cbs-ad-234x60", "cbs-pushdown", "cbs-ad-300x250-0", "ads_magnet"]);
#                     // -->
#                 </script>
#                         <div id="cbs-badge-notices-wrapper"></div>
#
#             <div id="fb-root"></div>
#         </div> <!-- cbs-page -->
#     <!--[if IE]>
#     </div>
#     <![endif]-->
#
#         <script type="text/javascript">
#             window.twttr = (function(d, s, id) {
#                 var t, js, fjs = d.getElementsByTagName(s)[0];
#                 if (d.getElementById(id)) return;
#                 js = d.createElement(s);
#                 js.id = id;
#                 js.src = "//platform.twitter.com/widgets.js";
#                 fjs.parentNode.insertBefore(js, fjs);
#                 return window.twttr || (t = {
#                         _e: [], ready: function(f) {
#                             t._e.push(f)
#                         }
#                     });
#             }(document, "script", "twitter-wjs"));
#
#         </script>
#
#         <script type="text/javascript">
#             var __n = "##CBS_COM##";
#         </script>
#
#
#                 <script type="text/javascript">
#
#             WebFontConfig = {
#                 google: {families: ['Maven Pro:400,700', 'Istok Web', 'Lato:900,700,400,300,100:latin']}       //    { families: ['Maven Pro:400,700', 'Istok Web', 'Lato:400,300,100:latin'] }
#             };
#             if (typeof WebFontActiveCallbacks !== 'undefined') {
#                 WebFontConfig.active = function() {
#                     for (var i = 0; i < WebFontActiveCallbacks.length; i++) {
#                         WebFontActiveCallbacks[i]();
#                     }
#                 }
#             }
#             (function() {
#                 var wf = document.createElement('script');
#                 wf.src = ('https:' == document.location.protocol ? 'https' : 'http') +
#                     '://ajax.googleapis.com/ajax/libs/webfont/1.5.18/webfont.js';
#                 wf.type = 'text/javascript';
#                 wf.async = 'true';
#                 var s = document.getElementsByTagName('script')[0];
#                 s.parentNode.insertBefore(wf, s);
#             })();
#
#         </script>
#
#         <div id="native_top"></div>
#
#         <script type="text/javascript">
#             window._taboola = window._taboola || [];
#             _taboola.push({flush: true});
#         </script>
#
#
# </body>
# </html>

# %%
#Parsing an Article
first_article.parse()
print(first_article.text)
print(first_article.top_image)
print(first_article.authors)
print(first_article.title)
print(first_article.images)
print(first_article.movies)
# Out:
# Forgot your password?
#
# Enter your email address below and we'll send you an email with instructions to create a new password.
# http://wwwimage5.cbsstatic.com/thumbnails/videos/w848/CBS_Production_Entertainment_VMS/2014/08/03/314615364002/CBS_AMAZING_RACE_101_CONTENT_CIAN_NY_369206_1296_1280x720_324694595831_407636_640x360.jpg
# []
# The Amazing Race Video
# {'http://www.cbs.com/assets/images/headers/close.png', 'http://www.cbs.com/assets/images/homepage/2016/cbs.svg', 'https://www.facebook.com/tr?id=1416158592005194&ev=NoScript', 'http://wwwimage5.cbsstatic.com/thumbnails/videos/w848/CBS_Production_Entertainment_VMS/2014/08/03/314615364002/CBS_AMAZING_RACE_101_CONTENT_CIAN_NY_369206_1296_1280x720_324694595831_407636_640x360.jpg'}
# []

# %%
#Performing NLP on an Article
first_article.nlp()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-16-f611a6b6a475> in <module>()
#       1 #Performing NLP on an Article
# ----> 2 first_article.nlp()
#
# /usr/local/lib/python3.5/dist-packages/newspaper3k-0.1.8-py3.5.egg/newspaper/article.py in nlp(self)
#     333         max_sents = self.config.MAX_SUMMARY_SENT
#     334
# --> 335         summary_sents = nlp.summarize(title=self.title, text=self.text, max_sents=max_sents)
#     336         summary = '\n'.join(summary_sents)
#     337         self.set_summary(summary)
#
# /usr/local/lib/python3.5/dist-packages/newspaper3k-0.1.8-py3.5.egg/newspaper/nlp.py in summarize(url, title, text, max_sents)
#      26
#      27     summaries = []
# ---> 28     sentences = split_sentences(text)
#      29     keys = keywords(text)
#      30     titleWords = split_words(title)
#
# /usr/local/lib/python3.5/dist-packages/newspaper3k-0.1.8-py3.5.egg/newspaper/nlp.py in split_sentences(text)
#     138     """
#     139     import nltk.data
# --> 140     tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
#     141
#     142     sentences = tokenizer.tokenize(text)
#
# /usr/local/lib/python3.5/dist-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     799
#     800     # Load the resource.
# --> 801     opened_resource = _open(resource_url)
#     802
#     803     if format == 'raw':
#
# /usr/local/lib/python3.5/dist-packages/nltk/data.py in _open(resource_url)
#     917
#     918     if protocol is None or protocol.lower() == 'nltk':
# --> 919         return find(path_, path + ['']).open()
#     920     elif protocol.lower() == 'file':
#     921         # urllib might not use mode='rb', so handle this one ourselves:
#
# /usr/local/lib/python3.5/dist-packages/nltk/data.py in find(resource_name, paths)
#     639     sep = '*' * 70
#     640     resource_not_found = '\n%s\n%s\n%s' % (sep, msg, sep)
# --> 641     raise LookupError(resource_not_found)
#     642
#     643
#
# LookupError:
# **********************************************************************
#   Resource 'tokenizers/punkt/PY3/english.pickle' not found.
#   Please use the NLTK Downloader to obtain the resource:  >>>
#   nltk.download()
#   Searched in:
#     - '/home/abhilash/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************
