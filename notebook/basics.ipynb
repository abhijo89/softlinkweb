# %%
import newspaper
newspaper.languages()
# Out:
# Your available languages are:
#
# input code		full name
#   ar			  Arabic
#   da			  Danish
#   de			  German
#   en			  English
#   es			  Spanish
#   fi			  Finnish
#   fr			  French
#   he			  Hebrew
#   hu			  Hungarian
#   id			  Indonesian
#   it			  Italian
#   ko			  Korean
#   mk			  Macedonian
#   nb			  Norwegian (Bokmål)
#   nl			  Dutch
#   no			  Norwegian
#   pt			  Portuguese
#   ru			  Russian
#   sv			  Swedish
#   tr			  Turkish
#   vi			  Vietnamese
#   zh			  Chinese

# %%
cbs_paper = newspaper.build('http://cbs.com', memoize_articles=False)
print (cbs_paper.size())
# Out:
# 227

# %%
# getting all categories 
cbs_paper.category_urls()
# Out:
# ['http://cbs.seenon.com',
#  'http://cbs.com',
#  'http://cbs.com/all-access',
#  'http://cbs.com/live-tv',
#  'http://www.cbs.com',
#  'http://cbs.com/superbowl',
#  'http://cbs.com/shows',
#  'http://cbs.com/schedule',
#  'http://cbs.com/cbs_cares',
#  'http://cbs.com/watch']

# %%
#Extracting Source brand & description
print(cbs_paper.brand)
print(cbs_paper.description)
# Out:
# cbs
# television, TV, video, CBS TV, Columbia Broadcast System, watch online video, watch tv, soap opera video, David Letterman, CSI, Big Brother, NCIS, The Price is Right, the Young and the Restless, Guiding Light, As the World Turns, Survivor, Two and a Half Men, The Amazing Race, Star Trek, Jericho.

# %%
# print all articles 
print(cbs_paper.articles[0].title)
print (len(cbs_paper.articles))
# Out:
#                                         Watch SB Commercial: Amazon - Echo Party
# 227

# %%
#Downloading an Article
first_article = cbs_paper.articles[0]
first_article.download()
print(first_article.html)
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" class="">
# <head>
#         <script type="text/javascript" src="//js-sec.indexww.com/ht/ls-cbs.js" async></script>
#         <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
#     <meta http-equiv="Content-Type" content="text/html;charset=utf-8"/>
#     <meta content="app-id=530168168" name="apple-itunes-app">
#     <meta property="og:site_name" content="CBS"/>
# <meta name="viewport" content="width=device-width, initial-scale=0.5, maximum-scale=1.0, user-scalable=no" />
#
#
#
#             <meta property="og:title" content="Super Bowl 50 Commercials Video - Amazon - Echo Party - CBS.com"/>
#
#             <meta property="og:description" content=""/>
#
#             <meta property="og:type" content="article"/>
#
#     <meta property="og:image" content=""/>
#
#
#
#
#
#         <meta name="twitter:site" content="@cbs">
#         <meta name="twitter:creator" content="@cbs">
# ...

# %%
#Parsing an Article
first_article.parse()
print(first_article.text)
print(first_article.top_image)
print(first_article.authors)
print(first_article.title)
print(first_article.images[0])
print(first_article.movies)
# Out:
# Forgot your password?
#
# Enter your email address below and we'll send you an email with instructions to create a new password.
# http://wwwimage1.cbsstatic.com/thumbnails/videos/w848/CBS_Production_Entertainment_VMS/2016/02/07/617969731820/11HALF_a_4AMD0121000H_Amazon_R_740893_640x360.jpg
# []
# Super Bowl 50 Commercials Video
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4bfacb6f929b> in <module>()
#       5 print(first_article.authors)
#       6 print(first_article.title)
# ----> 7 print(first_article.images[0])
#       8 print(first_article.movies)
#
# TypeError: 'set' object does not support indexing

# %%
#Performing NLP on an Article
first_article.nlp()
print(first_article.summary)
print(first_article.keywords)
print(first_article.canonical_link)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-8-d98fbc9d63f7> in <module>()
#       1 #Performing NLP on an Article
# ----> 2 first_article.nlp()
#       3 print(first_article.summary)
#       4 print(first_article.keywords)
#       5 print(first_article.canonical_link)
#
# c:\users\mastermind\appdata\local\programs\python\python35-32\lib\site-packages\newspaper\article.py in nlp(self)
#     322         self.set_keywords(keyws)
#     323
# --> 324         summary_sents = nlp.summarize(title=self.title, text=self.text)
#     325         summary = '\n'.join(summary_sents)
#     326         self.set_summary(summary)
#
# c:\users\mastermind\appdata\local\programs\python\python35-32\lib\site-packages\newspaper\nlp.py in summarize(url, title, text)
#      26
#      27     summaries = []
# ---> 28     sentences = split_sentences(text)
# ...

# %%
cbs_paper = newspaper.build('http://cbs.com', memoize_articles=False)

# %%
 for category in cbs_paper.category_urls():
        print (category)
